# %%
with open ("C:/Users/Venant/Desktop/basicscorpus/dc0.txt", "r") as g:
    docA=g.read() #document0 all words not tokenized
    bowA=docA.split(" ") #document0 words tokenezed using ""
    #print (bowA)
    #for i in g.readlines(): #this when you want to read the document line after line, it help in speeds
        #print('this is a line =>' +i)
with open ("C:/Users/Venant/Desktop/basicscorpus/dc1.txt", "r") as f:
    docB=f.read() #document1 all words not tokenized
    bowB=docB.split(" ") #document1 words tokenezed using ""
    #print (bowB)
with open ("C:/Users/Venant/Desktop/basicscorpus/dc2.txt", "r") as h:
    docC=h.read() #document2 all words not tokenized
    bowC=docC.split(" ") #document2 words tokenezed using ""
    #print (bowC)
wordSet= set(bowA).union(set(bowB)).union(set(bowC))
#print(wordSet)
#here is the set for all the tokens throughout the whole documents or corpus,without replicating the words
#set is used to avoid that replication.

#I'll create dictionaries to keep my words counts.
wordDictA=dict.fromkeys(wordSet, 0)
wordDictB=dict.fromkeys(wordSet, 0)
wordDictC=dict.fromkeys(wordSet, 0)

#This is what one(A) of them looks like
#print(wordDictA)
#print(wordDictB)
#print(wordDictC)

#Now I'll count the words in my bags.
for word in bowA:
    wordDictA[word]+=1
for word in bowB:
    wordDictB[word]+=1
for word in bowC:
    wordDictC[word]+=1
    
#print(wordDictC) #words in document 2 (or bag of word C) and their frenquence.

#Lastly I'll stick those into a matrix.
import pandas as pd
pd.DataFrame([wordDictA, wordDictB, wordDictC])
#boom!!! we just converted words into a linear algebra problem!
#Computers can handle linear algebra, mission accomplished.


#the error start below, 
#TF*IDF Better strategy, that above where we were just putting words in a matrix showing the frequecy of each word 
def computeTF(wordDict, bow):
    tfDict = {}
    bowCount = len(bow)
    for word, count in wordDict.iteritems():
        tfDict[word] = count/float(bowCount)
    return tfDict

tfBowA = computeTF(wordDictA, bowA)
tfBowB = computeTF(wordDictB, bowB)
tfBowC = computeTF(wordDictC, bowC)

def computeIDF(docList):
    import math
    idfDict = {}
    N = len(docList)
    
    #counts the number of documents that contain a word w
    idfDict = dict.fromkeys(docList[0].keys(),0)
    for doc in docList:
        for word, val in doc.iteritems():
            if val > 0:
                idfDict[word] +=1
                
    #divide N by denominator above, take the log of that
    for word, val in idfDict.iteritems():
        idfDict[word] = math.log(N/float(val))
        
    return idfDict

idfs = computeIDF([wordDictA, wordDictB, wordDictC])

#TFIDF computation 
def computeTFIDF(tfBow, idfs):
    tfdf = {}
    for word, val in tfBow.iteritems():
        tfidf[word] = val*idfs[words]
    return tfidf

tfidfBowA = computeTFIDF(tfBowA, idfs)
tfidfBowB = computeTFIDF(tfBowB, idfs)
tfidfBowC = computeTFIDF(tfBowC, idfs)

#Lastly I'll stick my tfidfs across documents into a matrix
import pandas as pd
pd.DataFrame([tfidfBowA, tfidfBowB, tfidfBowC])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-3f57ed6c4d10> in <module>()
#      52     return tfDict
#      53
# ---> 54 tfBowA = computeTF(wordDictA, bowA)
#      55 tfBowB = computeTF(wordDictB, bowB)
#      56 tfBowC = computeTF(wordDictC, bowC)
#
# <ipython-input-7-3f57ed6c4d10> in computeTF(wordDict, bow)
#      48     tfDict = {}
#      49     bowCount = len(bow)
# ---> 50     for word, count in wordDict.iteritems():
#      51         tfDict[word] = count/float(bowCount)
#      52     return tfDict
#
# AttributeError: 'dict' object has no attribute 'iteritems'
