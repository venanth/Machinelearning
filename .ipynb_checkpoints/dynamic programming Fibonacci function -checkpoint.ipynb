# %%
def fib(n):
    if n==1 or n==2:
        result =1
    else:
        result = fib(n-1) + fib(n-2)
    return result

# %%
fib(5)
# Out:
# 5

# %%
fib(20)
# Out:
# 6765

# %%
fib(35)
# Out:
# 9227465

# %%
def fib_2(n,memo):
    if memo[n] is not None:
        return memo[n]
    if n == 1 or n==2:
        result = 1
    else:
        result = fib_2(n-1,memo) + fib_2(n-2,memo)
        memo[n]=result
        return result
def fib_memo(n):
    memo = [None]*(n+1)
    return fib_2(n,memo)

# %%
fib_memo(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-9735aca1f45b> in <module>()
# ----> 1 fib_memo(5)
#
# <ipython-input-18-c8c0151a73f1> in fib_memo(n)
#      10 def fib_memo(n):
#      11     memo = [None]*(n+1)
# ---> 12     return fib_2(n,memo)
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
fib_memo(35)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-fa03495bf19f> in <module>()
# ----> 1 fib_memo(35)
#
# <ipython-input-18-c8c0151a73f1> in fib_memo(n)
#      10 def fib_memo(n):
#      11     memo = [None]*(n+1)
# ---> 12     return fib_2(n,memo)
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
fib_memo(100)
fib_memo(1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-d8725546163e> in <module>()
# ----> 1 fib_memo(100)
#       2 fib_memo(1000)
#
# <ipython-input-18-c8c0151a73f1> in fib_memo(n)
#      10 def fib_memo(n):
#      11     memo = [None]*(n+1)
# ---> 12     return fib_2(n,memo)
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# <ipython-input-18-c8c0151a73f1> in fib_2(n, memo)
#       5         result = 1
#       6     else:
# ----> 7         result = fib_2(n-1,memo) + fib_2(n-2,memo)
#       8         memo[n]=result
#       9         return result
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
def fib_bottom_up(n):
    if n== 1 or n ==2:
        return 1
    bottom_up = [None]*(n+1)
    bottom_up[1]=1
    bottom_up[2]=1
    for i in range(3,n+1):
        bottom_up[i] = bottom_up[i-1] + bottom_up[i-2]
        return bottom_up[n]

# %%
fib_bottom_up(35)

# %%
#correct this code please
