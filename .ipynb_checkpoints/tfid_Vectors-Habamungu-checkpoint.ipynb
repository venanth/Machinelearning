# %%
# include modules
from os import listdir #here we only want to import listdir"list directory",
#not the entire os module for the the sake of speed and memory 
from os.path import isfile, join #same here but what is isfile???
import math #here we are impoting math means all formulations and stuffs.
import re # regular expression
from pandas import DataFrame

# fetching documents
mypath = "C:/Users/Venant/Desktop/Habamungu"

filenames = [f for f in listdir(mypath) if isfile(join(mypath, f))]

docs = []
for file in filenames:
    file_path = mypath + '/' + file 
    with open(file_path) as f:
        str = ' '.join(f.readlines())
        docs.append(str)

tf_list = [] 
idf_list = []

# calculations
words = []
for doc in docs:
    words += doc.split()

# calculate tf
for word in words:
    lst = []
    for doc in docs:
        word_count = sum(1 for match in re.finditer(word, doc))
        total_word_count = len(words)
        tf = word_count / total_word_count
        lst.append(tf)
    tf_list.append(lst)
    
df_tf = DataFrame(tf_list)
print('Dataframe for tf:')
df_tf.index = words
df_tf.columns = filenames
#print(df_tf)
#print('\n\n')


# calculate idf

def get_doc_count(word, docs):
    doc_count = 0
    for doc in docs:
        if word in doc:
            doc_count += 1
    return doc_count

for word in words:
    lst = []
    total_doc_count = len(docs)
    doc_count = get_doc_count(word, docs)
    for doc in docs:
        idf = math.log(total_doc_count / doc_count)
        #idf = math.log((total_doc_count / doc_count) , 10)
        lst.append(idf)
    idf_list.append(lst)

df_idf = DataFrame(idf_list)
print('Dataframe for idf:')
df_idf.index = words
df_idf.columns = filenames
#print(df_idf)
#print('\n\n')

# calculate tf_idf
df_tf_idf = DataFrame(df_tf.values*df_idf.values, columns=filenames, index=words)
print('Dataframe for tf_idf:')
print(df_tf_idf)
print('\n\n') #adding double space among dataframes.
# Out:
# Dataframe for tf:
#           dc0.txt   dc1.txt   dc2.txt   dc3.txt   dc4.txt   dc5.txt
# man      0.046512  0.093023  0.023256  0.023256  0.023256  0.000000
# is       0.023256  0.023256  0.000000  0.000000  0.000000  0.023256
# worth    0.023256  0.000000  0.000000  0.000000  0.000000  0.000000
# a        0.093023  0.116279  0.093023  0.069767  0.093023  0.023256
# price    0.023256  0.000000  0.000000  0.000000  0.000000  0.000000
# of       0.023256  0.000000  0.000000  0.000000  0.000000  0.000000
# a        0.093023  0.116279  0.093023  0.069767  0.093023  0.023256
# woman    0.023256  0.023256  0.000000  0.000000  0.000000  0.000000
# man      0.046512  0.093023  0.023256  0.023256  0.023256  0.000000
# man      0.046512  0.093023  0.023256  0.023256  0.023256  0.000000
# is       0.023256  0.023256  0.000000  0.000000  0.000000  0.023256
# a        0.093023  0.116279  0.093023  0.069767  0.093023  0.023256
# man      0.046512  0.093023  0.023256  0.023256  0.023256  0.000000
# not      0.000000  0.023256  0.000000  0.000000  0.000000  0.000000
# woman    0.023256  0.023256  0.000000  0.000000  0.000000  0.000000
# respect  0.000000  0.000000  0.023256  0.023256  0.023256  0.046512
# the      0.000000  0.000000  0.046512  0.046512  0.046512  0.000000
# parents  0.000000  0.000000  0.023256  0.023256  0.023256  0.000000
# there    0.000000  0.000000  0.023256  0.023256  0.023256  0.000000
# are      0.000000  0.000000  0.046512  0.046512  0.046512  0.000000
# man      0.046512  0.093023  0.023256  0.023256  0.023256  0.000000
# as       0.000000  0.000000  0.023256  0.000000  0.023256  0.000000
# well     0.000000  0.000000  0.023256  0.000000  0.023256  0.000000
# respect  0.000000  0.000000  0.023256  0.023256  0.023256  0.046512
# the      0.000000  0.000000  0.046512  0.046512  0.046512  0.000000
# parents  0.000000  0.000000  0.023256  0.023256  0.023256  0.000000
# there    0.000000  0.000000  0.023256  0.023256  0.023256  0.000000
# are      0.000000  0.000000  0.046512  0.046512  0.046512  0.000000
# man      0.046512  0.093023  0.023256  0.023256  0.023256  0.000000
# respect  0.000000  0.000000  0.023256  0.023256  0.023256  0.046512
# the      0.000000  0.000000  0.046512  0.046512  0.046512  0.000000
# parents  0.000000  0.000000  0.023256  0.023256  0.023256  0.000000
# there    0.000000  0.000000  0.023256  0.023256  0.023256  0.000000
# are      0.000000  0.000000  0.046512  0.046512  0.046512  0.000000
# man      0.046512  0.093023  0.023256  0.023256  0.023256  0.000000
# as       0.000000  0.000000  0.023256  0.000000  0.023256  0.000000
# well     0.000000  0.000000  0.023256  0.000000  0.023256  0.000000
# respect  0.000000  0.000000  0.023256  0.023256  0.023256  0.046512
# respect  0.000000  0.000000  0.023256  0.023256  0.023256  0.046512
# is       0.023256  0.023256  0.000000  0.000000  0.000000  0.023256
# all      0.000000  0.000000  0.000000  0.000000  0.000000  0.023256
# you      0.000000  0.000000  0.000000  0.000000  0.000000  0.023256
# need     0.000000  0.000000  0.000000  0.000000  0.000000  0.023256
#
#
#
# Dataframe for idf:
#           dc0.txt   dc1.txt   dc2.txt   dc3.txt   dc4.txt   dc5.txt
# man      0.182322  0.182322  0.182322  0.182322  0.182322  0.182322
# is       0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# worth    1.791759  1.791759  1.791759  1.791759  1.791759  1.791759
# a        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# price    1.791759  1.791759  1.791759  1.791759  1.791759  1.791759
# of       1.791759  1.791759  1.791759  1.791759  1.791759  1.791759
# a        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# woman    1.098612  1.098612  1.098612  1.098612  1.098612  1.098612
# man      0.182322  0.182322  0.182322  0.182322  0.182322  0.182322
# man      0.182322  0.182322  0.182322  0.182322  0.182322  0.182322
# is       0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# a        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# man      0.182322  0.182322  0.182322  0.182322  0.182322  0.182322
# not      1.791759  1.791759  1.791759  1.791759  1.791759  1.791759
# woman    1.098612  1.098612  1.098612  1.098612  1.098612  1.098612
# respect  0.405465  0.405465  0.405465  0.405465  0.405465  0.405465
# the      0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# parents  0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# there    0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# are      0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# man      0.182322  0.182322  0.182322  0.182322  0.182322  0.182322
# as       1.098612  1.098612  1.098612  1.098612  1.098612  1.098612
# well     1.098612  1.098612  1.098612  1.098612  1.098612  1.098612
# respect  0.405465  0.405465  0.405465  0.405465  0.405465  0.405465
# the      0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# parents  0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# there    0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# are      0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# man      0.182322  0.182322  0.182322  0.182322  0.182322  0.182322
# respect  0.405465  0.405465  0.405465  0.405465  0.405465  0.405465
# the      0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# parents  0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# there    0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# are      0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# man      0.182322  0.182322  0.182322  0.182322  0.182322  0.182322
# as       1.098612  1.098612  1.098612  1.098612  1.098612  1.098612
# well     1.098612  1.098612  1.098612  1.098612  1.098612  1.098612
# respect  0.405465  0.405465  0.405465  0.405465  0.405465  0.405465
# respect  0.405465  0.405465  0.405465  0.405465  0.405465  0.405465
# is       0.693147  0.693147  0.693147  0.693147  0.693147  0.693147
# all      1.791759  1.791759  1.791759  1.791759  1.791759  1.791759
# you      1.791759  1.791759  1.791759  1.791759  1.791759  1.791759
# need     1.791759  1.791759  1.791759  1.791759  1.791759  1.791759
#
#
#
# Dataframe for tf_idf:
#           dc0.txt   dc1.txt   dc2.txt   dc3.txt   dc4.txt   dc5.txt
# man      0.008480  0.016960  0.004240  0.004240  0.004240  0.000000
# is       0.016120  0.016120  0.000000  0.000000  0.000000  0.016120
# worth    0.041669  0.000000  0.000000  0.000000  0.000000  0.000000
# a        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# price    0.041669  0.000000  0.000000  0.000000  0.000000  0.000000
# of       0.041669  0.000000  0.000000  0.000000  0.000000  0.000000
# a        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# woman    0.025549  0.025549  0.000000  0.000000  0.000000  0.000000
# man      0.008480  0.016960  0.004240  0.004240  0.004240  0.000000
# man      0.008480  0.016960  0.004240  0.004240  0.004240  0.000000
# is       0.016120  0.016120  0.000000  0.000000  0.000000  0.016120
# a        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# man      0.008480  0.016960  0.004240  0.004240  0.004240  0.000000
# not      0.000000  0.041669  0.000000  0.000000  0.000000  0.000000
# woman    0.025549  0.025549  0.000000  0.000000  0.000000  0.000000
# respect  0.000000  0.000000  0.009429  0.009429  0.009429  0.018859
# the      0.000000  0.000000  0.032239  0.032239  0.032239  0.000000
# parents  0.000000  0.000000  0.016120  0.016120  0.016120  0.000000
# there    0.000000  0.000000  0.016120  0.016120  0.016120  0.000000
# are      0.000000  0.000000  0.032239  0.032239  0.032239  0.000000
# man      0.008480  0.016960  0.004240  0.004240  0.004240  0.000000
# as       0.000000  0.000000  0.025549  0.000000  0.025549  0.000000
# well     0.000000  0.000000  0.025549  0.000000  0.025549  0.000000
# respect  0.000000  0.000000  0.009429  0.009429  0.009429  0.018859
# the      0.000000  0.000000  0.032239  0.032239  0.032239  0.000000
# parents  0.000000  0.000000  0.016120  0.016120  0.016120  0.000000
# there    0.000000  0.000000  0.016120  0.016120  0.016120  0.000000
# are      0.000000  0.000000  0.032239  0.032239  0.032239  0.000000
# man      0.008480  0.016960  0.004240  0.004240  0.004240  0.000000
# respect  0.000000  0.000000  0.009429  0.009429  0.009429  0.018859
# the      0.000000  0.000000  0.032239  0.032239  0.032239  0.000000
# parents  0.000000  0.000000  0.016120  0.016120  0.016120  0.000000
# there    0.000000  0.000000  0.016120  0.016120  0.016120  0.000000
# are      0.000000  0.000000  0.032239  0.032239  0.032239  0.000000
# man      0.008480  0.016960  0.004240  0.004240  0.004240  0.000000
# as       0.000000  0.000000  0.025549  0.000000  0.025549  0.000000
# well     0.000000  0.000000  0.025549  0.000000  0.025549  0.000000
# respect  0.000000  0.000000  0.009429  0.009429  0.009429  0.018859
# respect  0.000000  0.000000  0.009429  0.009429  0.009429  0.018859
# is       0.016120  0.016120  0.000000  0.000000  0.000000  0.016120
# all      0.000000  0.000000  0.000000  0.000000  0.000000  0.041669
# you      0.000000  0.000000  0.000000  0.000000  0.000000  0.041669
# need     0.000000  0.000000  0.000000  0.000000  0.000000  0.041669
